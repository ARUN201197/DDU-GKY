# %% [markdown]
# ### <center> ADMISSION DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.svm import LinearSVR
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
data  = pd.read_csv('./Admission_Predict_Ver1.1.csv')
data.head(10)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
# 5           6        330          115                  5  4.5   3.0  9.34
# 6           7        321          109                  3  3.0   4.0  8.20
# 7           8        308          101                  2  3.0   4.0  7.90
# 8           9        302          102                  1  2.0   1.5  8.00
# 9          10        323          108                  3  3.5   3.0  8.60
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65
# 5         1              0.90
# 6         1              0.75
# 7         0              0.68
# 8         0              0.50
# 9         0              0.45

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# 25%      3.00000    8.127500    0.000000           0.63000
# 50%      3.50000    8.560000    1.000000           0.72000
# 75%      4.00000    9.040000    1.000000           0.82000
# max      5.00000    9.920000    1.000000           0.97000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
data.shape
# Out:
# (500, 9)

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(['Research','Serial No.'], axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Chance of Admit '],
#       dtype='object')

# %%
data.rename(columns={'GRE Score':'GRE_Score','TOEFL Score':'TOEFL_Score','University Rating':'University_Rating','Chance of Admit ':'Chance_of_Admit'},inplace=True)

# %%
data.columns
# Out:
# Index(['GRE_Score', 'TOEFL_Score', 'University_Rating', 'SOP', 'LOR ', 'CGPA',
#        'Chance_of_Admit'],
#       dtype='object')

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Univariate Analysis

# %%
for i in data.columns:
    sns.histplot(x=data[i],kde = True)
    plt.show()

# %%
for i in data.columns:
    sns.boxplot(y=data[i])
    plt.show()

# %% [markdown]
# #### Removing outliers

# %%
def outlier_limit(col):
    Q1,Q3 = np.nanpercentile(col,[25,75])
    IQR = Q3-Q1
    UL = Q3 +1.5*IQR
    LL = Q1 - 1.5*IQR
    return LL,UL

# %%
LL,UL = outlier_limit(data['LOR '])
data['LOR '] = np.where((data['LOR ']>UL)|(data['LOR ']<LL),np.nan,data['LOR '])

# %%
LL,UL = outlier_limit(data['Chance_of_Admit'])
data['Chance_of_Admit'] = np.where((data['Chance_of_Admit']>UL)|(data['Chance_of_Admit']<LL),np.nan,data['Chance_of_Admit'])

# %%
for i in data.columns:
    sns.boxplot(y=data[i])
    plt.show()

# %%
data.dropna(inplace=True)

# %% [markdown]
# #### Multivariate Analysis

# %% [markdown]
# #### Scatterplot

# %%
sns.scatterplot(data=data,x='Chance_of_Admit',y='CGPA')
plt.show()

# %%
sns.scatterplot(data=data,x='Chance_of_Admit',y='GRE_Score')
plt.show()

# %%
sns.scatterplot(data=data,x='Chance_of_Admit',y='TOEFL_Score')
plt.show()

# %% [markdown]
# #### Heatmap

# %%
sns.heatmap(data.corr()[['Chance_of_Admit']].sort_values(by='Chance_of_Admit',ascending=False),vmin=-1,vmax=1,annot=True)
plt.show()

# %%
data = data[['GRE_Score','TOEFL_Score','CGPA','University_Rating','Chance_of_Admit']]

# %% [markdown]
# #### Selecting features and targets

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %% [markdown]
# #### Feature Scaling

# %% [markdown]
# #### Splitting the data into training and testing sets

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state=46,shuffle=True)

# %% [markdown]
# #### Initialising Standard Scaler

# %%
sc = StandardScaler()

# %%
x_train =sc.fit_transform(x_train)

# %%
x_test = sc.transform(x_test)

# %% [markdown]
# #### Model Building

# %%
models = {
    "LinearRegression":LinearRegression(),
    "Ridge":Ridge(),
    'Lasso':Lasso(),
    "LinearSVR":LinearSVR(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "GradientBoostingRegressor":GradientBoostingRegressor(),
    "AdaBoostRegressor":AdaBoostRegressor(),
    "RandomForestRegressor":RandomForestRegressor(random_state=0),
}

# %% [markdown]
# #### Initialising the model

# %%
model = LinearRegression()

# %% [markdown]
# #### Fittting the model with training data

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Predicting using the test data

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# #### Evaluating the accuracy

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8550427184123398

# %% [markdown]
# #### Testing the accuracy

# %%
model.score(x_test,y_test)
# Out:
# 0.8550427184123398

# %% [markdown]
# #### Training accuracy

# %%
model.score(x_train,y_train)
# Out:
# 0.8009157779707861

# %% [markdown]
# #### MAE

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.03416464490006874

# %% [markdown]
# #### MSE

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.002094163057349345

# %% [markdown]
# #### Rootmean squared error

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.04576202636847876

# %% [markdown]
# ####  Creating a dataframe with y_test and y_pred

# %%
Output = pd.DataFrame(zip(y_test,y_pred),columns=['Actual','Prediction'])

# %%
Output.head()
# Out:
#    Actual  Prediction
# 0    0.79    0.729914
# 1    0.42    0.509690
# 2    0.76    0.679948
# 3    0.65    0.683987
# 4    0.80    0.782703

# %% [markdown]
# #### Plotting the result

# %%
sns.regplot(data=Output,x='Actual',y='Prediction')
plt.show()

# %% [markdown]
# ## <center> OR

# %% [markdown]
# #### Using a for loop for model training and testing

# %%
for name,model in models.items():
    model.fit(x_train,y_train)
    print("model trained with {}".format(name))
    training_score = model.score(x_train,y_train)*100
    testing_score = model.score(x_test,y_test)*100
    score =r2_score(y_test,model.predict(x_test))*100
    mae = mean_absolute_error(y_test,model.predict(x_test))
    mse = mean_squared_error(y_test,model.predict(x_test))
    rmse = np.sqrt(mse)
    print("r2score: ",score)
    print("training_score: ",training_score)
    print("testing_score: ",testing_score)
    print("mae: ",mae)
    print("mse: ",mse)
    print("rmse_test: ",rmse)
    print("*"*100)
# Out:
# model trained with LinearRegression
# r2score:  85.50427184123399
# training_score:  80.0915777970786
# testing_score:  85.50427184123399
# mae:  0.03416464490006874
# mse:  0.002094163057349345
# rmse_test:  0.04576202636847876
# ****************************************************************************************************
# model trained with Ridge
# r2score:  85.49531167749024
# training_score:  80.09106515923212
# testing_score:  85.49531167749024
# mae:  0.03418977499137481
# mse:  0.002095457510701011
# rmse_test:  0.04577616749686469
# ****************************************************************************************************
# model trained with Lasso
# r2score:  -0.6799072993108446
# training_score:  0.0
# testing_score:  -0.6799072993108446
# mae:  0.09707556675062973
# mse:  0.014544984575753919
# rmse_test:  0.12060258942391709
# ****************************************************************************************************
# model trained with LinearSVR
# r2score:  85.29424630832668
# training_score:  79.18697239175859
# testing_score:  85.29424630832668
# mae:  0.034280832485701865
# mse:  0.0021245049420271834
# rmse_test:  0.04609235231605329
# ****************************************************************************************************
# model trained with DecisionTreeRegressor
# r2score:  56.02474187984019
# training_score:  99.82167281539756
# testing_score:  56.02474187984019
# mae:  0.05750000000000001
# mse:  0.006353
# rmse_test:  0.07970570870395671
# ****************************************************************************************************
# model trained with GradientBoostingRegressor
# r2score:  80.8393208560161
# training_score:  90.25379216436951
# testing_score:  80.8393208560161
# mae:  0.03845798248360329
# mse:  0.002768097330301409
# rmse_test:  0.05261271072945595
# ****************************************************************************************************
# model trained with AdaBoostRegressor
# r2score:  78.7140907082875
# training_score:  81.3361773013819
# testing_score:  78.7140907082875
# mae:  0.04350596742795144
# mse:  0.003075124229191405
# rmse_test:  0.055453802657630294
# ****************************************************************************************************
# model trained with RandomForestRegressor
# r2score:  77.09614906733408
# training_score:  96.46964659756354
# testing_score:  77.09614906733408
# mae:  0.04270416666666673
# mse:  0.0033088643750000058
# rmse_test:  0.057522729203333234
# ****************************************************************************************************

# %% [markdown]
# #### Using Randomforestregressor

# %% [markdown]
# #### Initialising the model

# %%
model = RandomForestRegressor()

# %% [markdown]
# #### Fitting the model with training data

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### Predicting using the test data

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# #### Evaluating the accuracy

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7738015830289202

# %% [markdown]
# #### Testing the accuracy

# %%
model.score(x_test,y_test)
# Out:
# 0.7738015830289202

# %% [markdown]
# #### Training accuracy

# %%
model.score(x_train,y_train)
# Out:
# 0.9658494744950845

# %% [markdown]
# #### MAE

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.04309558333333339

# %% [markdown]
# #### MSE

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.003267834242361116

# %% [markdown]
# #### Root Mean Squared Error

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.057164973912012904

# %% [markdown]
# #### Creating a dataframe with y_test and y_pred

# %%
Output = pd.DataFrame(zip(y_test,y_pred),columns=['actual','prediction'])

# %%
Output.head()
# Out:
#    actual  prediction
# 0    0.79      0.7206
# 1    0.42      0.4880
# 2    0.76      0.6756
# 3    0.65      0.6405
# 4    0.80      0.7960

# %% [markdown]
# #### Plotting the result

# %%
sns.regplot(data=Output,x='actual',y = 'prediction')
plt.show()

# %%
bestmodel = GradientBoostingRegressor().fit(x_train,y_train)
y_pred = bestmodel.predict(x_test)
score = r2_score(y_test,y_pred)*100
print("Score before hyper parameter  tuning is : {}".format(score))
# Out:
# Score before hyper parameter  tuning is : 80.88065002430014

# %%
GBR =GradientBoostingRegressor()

# %%
parameters = {"learning_rate":[0.1,0.2,0.3,0.4],
              "n_estimators":[100,200,300],
              "subsample":[1.0,1.2,1.4,1.6],
              "max_depth":[3,4,5]
             }

# %%
gridGBR = GridSearchCV(estimator=GBR,param_grid=parameters,cv=2,n_jobs=-1,verbose=-1)

# %%
gridGBR.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=2, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2, 0.3, 0.4],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [1.0, 1.2, 1.4, 1.6]},
#              verbose=-1)

# %%
gridGBR.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}

# %%
gridGBR_tuned = GradientBoostingRegressor(learning_rate= 0.1, max_depth= 4, n_estimators=100, subsample= 1.0)

# %%
gridGBR_tuned.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=4)

# %%
y_pred_gbr = gridGBR_tuned.predict(x_test)

# %%
score = r2_score(y_test,y_pred_gbr)
mae = mean_absolute_error(y_test,y_pred_gbr)
mse = mean_squared_error(y_test,y_pred_gbr)
rmse = np.sqrt(mse)

# %%
predict = gridGBR_tuned.predict(x)

# %%
Chance_of_Admit = data.Chance_of_Admit.values

# %%
PREDICT = pd.DataFrame(zip(Chance_of_Admit,predict),columns=("ACTUAL","PREDICTION"))

# %%
PREDICT.head()
# Out:
#    ACTUAL  PREDICTION
# 0    0.92    0.967029
# 1    0.76    0.967029
# 2    0.72    0.967029
# 3    0.80    0.967029
# 4    0.65    0.967029

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./titanic.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.heatmap(data.corr(),annot= True)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation = 90)
plt.stackplot(data.Age,data.Pclass, data.Survived)
plt.show()

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.boxplot(data=data, y="Age" )
plt.show()

# %%
sns.barplot(data=data, x='Pclass', y='Age', hue= 'Sex')
plt.show()

# %%
sns.barplot(data=data, x='Pclass', y='Survived', hue= 'Sex')
plt.show()

# %%
sns.countplot(data=data, x='Survived', hue='Pclass');

# %%
sns.countplot(data=data, hue='Survived', x='Pclass');

# %%
plt.figure(figsize=(10,6))
plt.ylabel('Survived')
plt.xlabel('Age')
plt.title('Survived / Age')
sns.lineplot(data=data,y='Survived', x='Age')
plt.show()

# %%
class_survived_age = data[['Survived','Age','Pclass','Sex']]
class_survived_age
# Out:
#      Survived   Age  Pclass     Sex
# 0           0  22.0       3    male
# 1           1  38.0       1  female
# 2           1  26.0       3  female
# 3           1  35.0       1  female
# 4           0  35.0       3    male
# ..        ...   ...     ...     ...
# 886         0  27.0       2    male
# 887         1  19.0       1  female
# 888         0   NaN       3  female
# 889         1  26.0       1    male
# 890         0  32.0       3    male
#
# [891 rows x 4 columns]

# %%
sns.heatmap(class_survived_age.corr(),annot=True);

# %%
class_survived_age.describe()
# Out:
#          Survived         Age      Pclass
# count  891.000000  714.000000  891.000000
# mean     0.383838   29.699118    2.308642
# std      0.486592   14.526497    0.836071
# min      0.000000    0.420000    1.000000
# 25%      0.000000   20.125000    2.000000
# 50%      0.000000   28.000000    3.000000
# 75%      1.000000   38.000000    3.000000
# max      1.000000   80.000000    3.000000

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.heatmap(data.corr(), annot=True);

# %%
# Create a DataFrame
#df = pd.DataFrame({'Column1': [1, 2, 3, 4, 5]})

# Replace specific values in 'Column1' with a new value
old_value = 3
new_value = 10
data['Sex'] = data['Sex'].replace('male', 1)
data['Sex'] = data['Sex'].replace('female', 0)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
sns.heatmap(data.corr(), annot= True);

# %%
sns.regplot(data=data,x='Sex',y='Survived');

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
plt.figure(figsize=(6,10))
plt.xticks(rotation=90)
sns.boxplot(data=data, y='Age')
plt.show()

# %% [markdown]
# ### The boarding points have higher fare value

# %%
sns.barplot(data=data,x='Embarked', y='Fare');

# %%
"""THE PEOPLES FROM CHEMBERG BOARDING POINT HAS PAID MORE FARE THAN OTHER BOARDING POINTS """
# Out:
# 'THE PEOPLES FROM CHEMBERG BOARDING POINT HAS PAID MORE FARE THAN OTHER BOARDING POINTS '

# %%
sns.lineplot(data=data,x='Embarked', y='Fare');

# %%
data.Embarked.value_counts().index
# Out:
# Index(['S', 'C', 'Q'], dtype='object')

# %%
palatte_color = sns.color_palette('dark')

# %%
plt.pie(data=data, x=data.Embarked.value_counts(),explode = [0.1, 0,0],colors=palatte_color,labels = ['S', 'C', 'Q'],autopct='%0.2f%%');

# %% [markdown]
# ### Pie plot using matplotlib with groupby

# %%
Pclass_survived = data.groupby(['Pclass'])['Survived'].sum()
Pclass_survived.plot.pie(legend=True,explode=[0,0.1,0.1],autopct='%0.2f%%');

# %% [markdown]
# ### Pie plot using matplotlib without groupby

# %%
Pclass_survived
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
plt.pie(data=data,\
x=data.Pclass.value_counts(),\
        explode=[0.1,0.1,0.1],\
labels=['S', 'C', 'Q'],\
autopct='%0.2f%%');

# %%
sns.scatterplot(data=data,x='Age',y='Fare',hue='Sex',size='Pclass');
